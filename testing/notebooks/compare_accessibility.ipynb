# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import route_planning.helpers.route_planning_helper as rp_helper
import config

# %%
# get a graph of Donegal that has all roads, walkways etc
# G_all_donegal = ox.graph_from_place("Donegal, Ireland", network_type="all")
# ox.save_graphml(G_all_donegal, filepath=f"{config.testing_graphml_path}/testing_graph.graphml")


G_all_donegal = ox.load_graphml(filepath=f"{config.testing_graphml_path}/testing_graph.graphml")
# add edge weight attribute
nx.set_edge_attributes(G_all_donegal, 1.0, "weight")
ox.plot_graph(G_all_donegal)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc5adc94580>)

# %%
# load the graph with labelled bus stops
G_with_routes = ox.load_graphml(filepath=f"{config.testing_graphml_path}/actual_routes_added.graphml")
rp_helper.convert_edge_weights_to_floats(G_with_routes)
ox.plot_graph(G_with_routes)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc5b9ffbee0>)

# %%
# merge routes data into the testing graph
test_nodes, test_edges = ox.graph_to_gdfs(G_all_donegal)
len(test_nodes)
# Out:
# 24742

# %%
route_nodes, route_edges = ox.graph_to_gdfs(G_with_routes)
bool_replace = {"True": True, "False": False}
route_nodes["community_route"] = route_nodes["community_route"].map(bool_replace).fillna(False)
# merged_nodes["community_route"] = merged_nodes["community_route"].fillna(False)
route_nodes["actual_stop"] = route_nodes["actual_stop"].map(bool_replace).fillna(False)

len(route_nodes)
# Out:
# 3579

# %%
actual_stop_nodes = route_nodes[route_nodes["actual_stop"]]["osmid"].tolist()
len(actual_stop_nodes)
# Out:
# 122

# %%
merged_nodes = gpd.sjoin(test_nodes, route_nodes,
                         how="left", op="intersects")


    #test_nodes.merge(route_nodes, on="osmid", how="left")
len(merged_nodes)
# Out:
# 24742

# %%
merged_nodes.head()
# Out:
#                y_left    x_left  osmid_left highway_left  \
# 2907242498  54.865236 -7.508191  2907242498          NaN
# 780664835   54.972684 -7.709056   780664835          NaN
# 2114650125  55.036243 -7.383424  2114650125          NaN
# 3778150429  54.852483 -7.525723  3778150429          NaN
# 1417674781  55.225775 -7.085802  1417674781          NaN
#
#                              geometry   index_right    y_right   x_right  \
# 2907242498  POINT (-7.50819 54.86524)           NaN        NaN       NaN
# 780664835   POINT (-7.70906 54.97268)  7.806648e+08  54.972684 -7.709056
# 2114650125  POINT (-7.38342 55.03624)           NaN        NaN       NaN
# 3778150429  POINT (-7.52572 54.85248)           NaN        NaN       NaN
# 1417674781  POINT (-7.08580 55.22577)  1.417675e+09  55.225775 -7.085802
#
#              osmid_right community                    rank top_n route_flag  \
# 2907242498           NaN       NaN                     NaN   NaN        NaN
# 780664835   7.806648e+08        10   0.0002789561526694481     0          0
# 2114650125           NaN       NaN                     NaN   NaN        NaN
# 3778150429           NaN       NaN                     NaN   NaN        NaN
# 1417674781  1.417675e+09         1  0.00020443990694311745     0          0
#
#            community_route community_route_order connection connection_order  \
# 2907242498             NaN                   NaN        NaN              NaN
# 780664835            False                    -1       None               -1
# 2114650125             NaN                   NaN        NaN              NaN
# 3778150429             NaN                   NaN        NaN              NaN
# 1417674781           False                   101       None               99
#
#            actual_stop actual_route_order highway_right
# 2907242498         NaN                NaN           NaN
# 780664835        False                NaN           NaN
# 2114650125         NaN                NaN           NaN
# 3778150429         NaN                NaN           NaN
# 1417674781       False                NaN           NaN

# %%
# remove duplicate columns introduced in merge, these are all default values
merged_nodes = merged_nodes.loc[:,~merged_nodes.columns.str.endswith("_right")]
merged_nodes.head()
# Out:
#                y_left    x_left  osmid_left highway_left  \
# 2907242498  54.865236 -7.508191  2907242498          NaN
# 780664835   54.972684 -7.709056   780664835          NaN
# 2114650125  55.036243 -7.383424  2114650125          NaN
# 3778150429  54.852483 -7.525723  3778150429          NaN
# 1417674781  55.225775 -7.085802  1417674781          NaN
#
#                              geometry community                    rank top_n  \
# 2907242498  POINT (-7.50819 54.86524)       NaN                     NaN   NaN
# 780664835   POINT (-7.70906 54.97268)        10   0.0002789561526694481     0
# 2114650125  POINT (-7.38342 55.03624)       NaN                     NaN   NaN
# 3778150429  POINT (-7.52572 54.85248)       NaN                     NaN   NaN
# 1417674781  POINT (-7.08580 55.22577)         1  0.00020443990694311745     0
#
#            route_flag community_route community_route_order connection  \
# 2907242498        NaN             NaN                   NaN        NaN
# 780664835           0           False                    -1       None
# 2114650125        NaN             NaN                   NaN        NaN
# 3778150429        NaN             NaN                   NaN        NaN
# 1417674781          0           False                   101       None
#
#            connection_order actual_stop actual_route_order
# 2907242498              NaN         NaN                NaN
# 780664835                -1       False                NaN
# 2114650125              NaN         NaN                NaN
# 3778150429              NaN         NaN                NaN
# 1417674781               99       False                NaN

# %%
# remove "_left" from remaining column names
merged_nodes.columns = [col.replace("_left", "") for col in merged_nodes.columns]
merged_nodes.head()
# Out:
#                     y         x       osmid highway  \
# 2907242498  54.865236 -7.508191  2907242498     NaN
# 780664835   54.972684 -7.709056   780664835     NaN
# 2114650125  55.036243 -7.383424  2114650125     NaN
# 3778150429  54.852483 -7.525723  3778150429     NaN
# 1417674781  55.225775 -7.085802  1417674781     NaN
#
#                              geometry community                    rank top_n  \
# 2907242498  POINT (-7.50819 54.86524)       NaN                     NaN   NaN
# 780664835   POINT (-7.70906 54.97268)        10   0.0002789561526694481     0
# 2114650125  POINT (-7.38342 55.03624)       NaN                     NaN   NaN
# 3778150429  POINT (-7.52572 54.85248)       NaN                     NaN   NaN
# 1417674781  POINT (-7.08580 55.22577)         1  0.00020443990694311745     0
#
#            route_flag community_route community_route_order connection  \
# 2907242498        NaN             NaN                   NaN        NaN
# 780664835           0           False                    -1       None
# 2114650125        NaN             NaN                   NaN        NaN
# 3778150429        NaN             NaN                   NaN        NaN
# 1417674781          0           False                   101       None
#
#            connection_order actual_stop actual_route_order
# 2907242498              NaN         NaN                NaN
# 780664835                -1       False                NaN
# 2114650125              NaN         NaN                NaN
# 3778150429              NaN         NaN                NaN
# 1417674781               99       False                NaN

# %%
# check that all "actual" stops are present
merged_actual_stop_nodes = merged_nodes[merged_nodes["actual_stop"] == True]["osmid"].tolist()
len(merged_actual_stop_nodes)
# Out:
# 119

# %%
# find the 2 missing nodes
diff = set(actual_stop_nodes).difference(merged_actual_stop_nodes)
diff
# Out:
# {258453072, 320673554, 2411894191}

# %%
merged_nodes.loc[merged_nodes["osmid"].isin(diff)]
# Out:
#                    y         x      osmid highway                   geometry  \
# 320673554  54.932912 -7.596713  320673554     NaN  POINT (-7.59671 54.93291)
# 258453072  55.334708 -7.286484  258453072     NaN  POINT (-7.28648 55.33471)
#
#           community rank top_n route_flag community_route  \
# 320673554       NaN  NaN   NaN        NaN             NaN
# 258453072       NaN  NaN   NaN        NaN             NaN
#
#           community_route_order connection connection_order actual_stop  \
# 320673554                   NaN        NaN              NaN         NaN
# 258453072                   NaN        NaN              NaN         NaN
#
#           actual_route_order
# 320673554                NaN
# 258453072                NaN

# %%
merged_nodes.loc[(merged_nodes["osmid"] == 320673554), "actual_stop"] = True
merged_nodes.loc[(merged_nodes["osmid"] == 258453072), "actual_stop"] = True
len(merged_nodes[merged_nodes["actual_stop"] == True]["osmid"])

# merged_nodes[merged_nodes["osmid"]]
# Out:
# 121

# %%
# check that all generated stops were added
connecting_labels = ["a", "b", "c", "d"]
connection_present = merged_nodes["connection"].isin(connecting_labels).value_counts()
connection_present.values[1] + len(merged_nodes[merged_nodes["community_route"] == True])
# Out:
# 390

# %%
# 8 missing, compare community route nodes first
community_route_nodes = route_nodes[route_nodes["community_route"]]["osmid"].tolist()
len(community_route_nodes)
# Out:
# 316

# %%
merged_community_route_nodes = merged_nodes[merged_nodes["community_route"] == True]["osmid"].tolist()
len(merged_community_route_nodes)
# Out:
# 308

# %%
# Find missing nodes
diff = set(community_route_nodes).difference(merged_community_route_nodes)
diff
# Out:
# {258438551,
#  258466029,
#  320673554,
#  821215522,
#  1417678858,
#  1556355680,
#  2111294750,
#  2907774312}

# %%
# update those nodes
for d in diff:
    merged_nodes.loc[(merged_nodes["osmid"] == d), "community_route"] = True
len(merged_nodes[merged_nodes["community_route"] == True]["osmid"])
# Out:
# 316

# %%
test_edges.head()
# Out:
#                     osmid  ref       highway  oneway   length  \
# 0               182668958  N14         trunk   False  826.234
# 1               182668958  N14         trunk   False  735.144
# 2  [374424339, 287062886]  NaN  unclassified   False   73.962
# 3  [374424339, 374424926]  NaN  unclassified   False  912.414
# 4                67774207  NaN      tertiary   False   34.944
#
#                                             geometry  weight name bridge  \
# 0  LINESTRING (-7.50819 54.86524, -7.50788 54.864...     1.0  NaN    NaN
# 1  LINESTRING (-7.50819 54.86524, -7.50841 54.865...     1.0  NaN    NaN
# 2  LINESTRING (-7.50819 54.86524, -7.50797 54.865...     1.0  NaN    NaN
# 3  LINESTRING (-7.50819 54.86524, -7.50845 54.865...     1.0  NaN    NaN
# 4  LINESTRING (-7.70906 54.97268, -7.70870 54.97292)     1.0  NaN    NaN
#
#   lanes maxspeed access width service junction tunnel area           u  \
# 0   NaN      NaN    NaN   NaN     NaN      NaN    NaN  NaN  2907242498
# 1   NaN      NaN    NaN   NaN     NaN      NaN    NaN  NaN  2907242498
# 2   NaN      NaN    NaN   NaN     NaN      NaN    NaN  NaN  2907242498
# 3   NaN      NaN    NaN   NaN     NaN      NaN    NaN  NaN  2907242498
# 4   NaN      NaN    NaN   NaN     NaN      NaN    NaN  NaN   780664835
#
#             v  key
# 0  7802305734    0
# 1  7802305709    0
# 2  1514185751    0
# 3  1514179617    0
# 4   818377528    0

# %%
# add edge weights
# populated_edges = route_edges[route_edges["weight"] > 1]
# len(populated_edges)
# Out:
# 1401

# %%
# populated_edges.head()
# Out:
#                      osmid   ref    highway  oneway    length  \
# 2                 24243010  R239  secondary   False  2188.718
# 5                226720237  R238  secondary   False   297.747
# 34               129304808  R238  secondary   False   887.556
# 38  [370868488, 370869445]  R238  secondary   False   438.967
# 45               370868489  R238  secondary   False   231.536
#
#                                              geometry  weight maxspeed lanes  \
# 2   LINESTRING (-7.40146 55.05867, -7.40079 55.059...   463.0       80   NaN
# 5   LINESTRING (-7.43141 55.06528, -7.43107 55.065...   109.0      NaN     2
# 34  LINESTRING (-7.22784 55.09832, -7.22883 55.097...   135.0      100     2
# 38  LINESTRING (-7.45066 55.07660, -7.45045 55.076...     5.0      NaN   NaN
# 45  LINESTRING (-7.46120 55.08284, -7.46112 55.082...   135.0      NaN   NaN
#
#    name bridge junction width tunnel access           u           v  key
# 2   NaN    NaN      NaN   NaN    NaN    NaN  2114650363  1411721776    0
# 5   NaN    NaN      NaN   NaN    NaN    NaN  2114650574  2114649685    0
# 34  NaN    NaN      NaN   NaN    NaN    NaN  1411715929  1315472999    0
# 38  NaN    NaN      NaN   NaN    NaN    NaN  2679019572  2114649718    0
# 45  NaN    NaN      NaN   NaN    NaN    NaN  2114692414   258430916    0

# %%
# i = 0
# for index, row in populated_edges.iterrows():
#     test_edges.loc[
#         (test_edges["geometry"] == row["geometry"]), "weight"] = row["weight"]
#     i += 1
#     print(i)
# Out:
# 24243010
# 226720237
# 129304808
# [370868488, 370869445]
# 370868489
# [234652016, 234652002, 234651994]
# [370868489, 370869445]
# 131652365
# 370868489
# 24243010
# 42389492
# 24243010
# 116758170
# 24243010
# 24243010
# 24243010
# 24243010
# 24243010
# 30727892
# 234652002
# 77630071
# 116758170
# 116758170
# 25525896
# 25525896
# 30726123
# 131652365
# 131652365
# 370868489
# 374315811
# 370868489
# [668274666, 24351103]
# 226720237
# 42389492
# 24243010
# [129304808, 668274667]
# 226720261
# 226720237
# 24351103
# 30726123
# 226720237
# [370868488, 370869445]
# [370868488, 226720237]
# 30504607
# 226720261
# [24243008, 303016529, 303016530]
# 303004298
# 303004298
# 303004298
# 178231317
# 370878874
# 370878874
# 24243008
# [231277268, 24242997, 231277270]
# [668261546, 517920954]
# 23848297
# [302947250, 302947246]
# 668261534
# [143950018, 339564174, 339564175]
# 231267773
# 668261534
# 668261534
# 302757359
# [201554584, 520021002, 201554570, 520020979]
# 562301519
# 302728952
# 189832516
# [243108144, 243108142, 231267773, 23866318]
# [143950018, 339564174, 339564175]
# [231267769, 231267771, 231267773]
# 302735492
# 142200862
# 28217669
# [303004298, 28217663, 303004295]
# 142200331
# 142200862
# 142714969
# 178231317
# [367822226, 302601324, 302601325]
# [767664611, 767664612, 207631509]
# 302728952
# 128244534
# 302735492
# 243071967
# 302735492
# 367822226
# [24243008, 303016529, 303016530]
# [475267684, 475267685, 475267695, 24251506, 150409461]
# 23848298
# 339564168
# [520020992, 520020995, 668085061, 520021005, 520021009, 668085076, 520020982]
# [339564168, 595828713, 339564171]
# 24242998
# 303004298
# 303004298
# [339564168, 595828713, 339564171]
# 801300938
# [801300937, 367822227, 562307245]
# 142714969
# [520021945, 668060349]
# [520021945, 668060349]
# [201554584, 520021002, 520020979, 201554570]
# 23848298
# 23848298
# 520021945
# 370878874
# 189832516
# 32048771
# 32048771
# [189920773, 189920775, 413744682, 413744685, 189920757]
# 143866831
# 32049669
# 32049670
# 23848294
# [142714553, 195823166]
# 143950018
# 142201843
# 361807999
# 28222375
# [302446585, 128243495]
# 142715220
# [302446584, 595828713, 595828714]
# 668053770
# 23364544
# 31672217
# 31672217
# 142715839
# 668053770
# 302735492
# [302769186, 302777091, 302769187, 189916901, 189916907, 302770415, 143861431]
# 28217753
# 142201843
# 23848298
# 370878874
# [302728953, 302735490, 302728950, 302728951]
# [370878874, 439829918, 439829919]
# 370878874
# [370924928, 370924929, 28221461]
# 431761210
# 143866831
# 520021009
# 142715839
# 302735492
# 302735492
# [339564168, 302757354, 302757355]
# 189832516
# 67775337
# 714403158
# [370167176, 370167177]
# [64963218, 370170187, 370169838]
# 64963218
# 179451341
# 67775337
# [130274908, 448669582]
# 179455236
# [370169312, 370167176]
# 179451341
# 179451341
# 714403158
# [448660364, 370169310]
# 64963218
# 714403158
# 714403158
# 375426524
# [712127779, 62154276]
# 448656438
# 714403158
# 448656438
# 448656438
# 67774207
# 67774207
# 67775337
# 714403158
# 714403158
# 179451341
# 130254965
# 67775326
# 714403158
# [62099073, 62099067, 62099071]
# 67775337
# 307098652
# 714403157
# 67775337
# 375428285
# 67775337
# 448656438
# 67775337
# [67775337, 448656438]
# 36821982
# 63514888
# 67774207
# 64889133
# [370169984, 370170187]
# 307098652
# 714403158
# 130254965
# 714403158
# 130254965
# 179455236
# [55933556, 754346837, 754346836]
# 201187918
# 201187918
# 24242993
# [231386418, 371520366]
# 352793504
# [297398473, 371583707]
# 297398473
# 371599889
# 371599889
# 185162342
# 231386418
# 672408628
# 30728340
# 24242993
# 30728343
# 30728340
# [370968160, 76187785]
# 266838748
# 266838748
# 266838748
# 266838748
# 76187785
# 131652750
# 352793504
# [371576421, 371576422]
# 371576420
# 30728340
# [672408626, 370926925, 370926926]
# [371520365, 371520366, 371520367, 371520368, 371574587]
# [297398473, 371583707]
# 352793504
# [816965099, 352793500, 778106631]
# [287708515, 371576423]
# [371574587, 371576420, 371574589]
# [672408626, 370926925, 370926926]
# 24242993
# 672408626
# 201187918
# 201187918
# [371519297, 243064137, 371519298, 370878875]
# 352793504
# 371599889
# 352793504
# 352793504
# 352793504
# 352793504
# 352793504
# 28221740
# 266838748
# [371532280, 297398475]
# 371599889
# 371599889
# 371599889
# [371599889, 303418194]
# [303395224, 632327628]
# [306328121, 632327627]
# 371860589
# [29151235, 632327625, 632327626, 371783499, 371783501]
# 177805084
# [178237864, 29151082, 370450812, 370450810]
# 372091346
# 372091346
# 178237864
# [303883751, 448738668, 632327631, 372091345, 303883737]
# 371860589
# 371860589
# 65067243
# 65067243
# [371634864, 65067243]
# 371860589
# [303883751, 448738668, 632327631, 372091345, 303883737]
# 303632899
# 303632899
# 448738667

# %%
# recreate test graph with route data included
G = ox.graph_from_gdfs(merged_nodes, test_edges)
len(G.nodes)
# Out:
# 24742

# %%
ox.save_graphml(G, filepath=f"{config.testing_graphml_path}/merged_routes.graphml")

# %%
ox.plot_graph(G)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

nodes, edges = ox.graph_to_gdfs(G)
nodes = nodes[nodes["community_route"] == True]
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_facecolor("black")

plt.rc("legend", fontsize=25,
       facecolor="black")

edges.plot(
    ax=ax,
    edgecolor="grey",
    linewidth=1,
    facecolor="none",
    zorder=1,
    alpha=0.8
)

nodes.plot(
    ax=ax,
    marker="o",
    markersize=100,
    column="community",
    cmap="hsv",
    zorder=2,
    #legend=legend,
    categorical=True
)

# %%
# test = nx.generators.ego_graph(G_with_routes, 2431959018, radius=150)
# ox.plot_graph(test)
